# %%
import pandas as pd

import nltk
from nltk.corpus import stopwords

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

import re
import string

# %%
df_1 = pd.read_csv('/kaggle/input/masculinity-saturday-twitter-sentiment-analysis/twitter_sentiment_analysis_masculinity_saturday_data_annotated.csv', index_col=0)

# %%
df_clean = pd.read_csv('/kaggle/input/sentiment-analysis-munged-data/amerix_sentiment_analysis_preprocessed_data.csv')

# %%
df_clean.head()
# Out:
#    Unnamed: 0     tweet_created_at  \
# 0           0  2022-12-30 22:37:46
# 1           1  2022-12-30 22:30:58
# 2           2  2022-12-30 22:18:00
# 3           3  2022-12-30 20:42:54
# 4           4  2022-12-30 20:32:23
#
#                                                 text  Sentiment
# 0  men refused listen toattend amerix classes men...          0
# 1                        ovobrezzzy take amerix next          2
# 2  ayodeleyo amerix nah i m good masculinity heal...          1
# 3       amerixdontsimp there need dating first place          0
# 4  dyeanna amerix kibe from cos nothing changing ...          1

# %%
df_1.head()
# Out:
#             tweet_created_at  \
# 0  2022-12-30 22:37:46+00:00
# 1  2022-12-30 22:30:58+00:00
# 2  2022-12-30 22:18:00+00:00
# 3  2022-12-30 20:42:54+00:00
# 4  2022-12-30 20:32:23+00:00
#
#                                                 text  Positive  Negative  \
# 0  Men who have refused to listen to/attend @amer...     0.000     0.073
# 1                       @OvOBrezzzy Take amerix next     0.000     0.000
# 2  @AyodeleYo11 @amerix Nah I’m good my masculini...     0.493     0.068
# 3  @Amerix_DontSimp There is no need for dating i...     0.000     0.180
# 4  @DyeAnna7 @amerix @kibe From what cos nothing ...     0.110     0.000
#
#    Neutral  Compound Sentiment
# 0    0.927   -0.2960  Negative
# 1    1.000    0.0000   Neutral
# 2    0.439    0.8271  Positive
# 3    0.820   -0.2960  Negative
# 4    0.890    0.6908  Positive

# %%
df_1.columns
# Out:
# Index(['tweet_created_at', 'text', 'Positive', 'Negative', 'Neutral',
#        'Compound', 'Sentiment'],
#       dtype='object')

# %%
text = " ".join(i for i in df_1.text)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

plt.figure( figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
negative =' '.join([i for i in df_1['text'][df_1["Negative"] > df_1["Positive"]]])

stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(negative)

plt.figure( figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
positive =' '.join([i for i in df_1['text'][df_1["Positive"] > df_1["Negative"]]])

stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(positive)

plt.figure( figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text = " ".join(i for i in df_clean.text)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

plt.figure( figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
